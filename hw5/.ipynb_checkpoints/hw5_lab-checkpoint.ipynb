# %% [markdown]
# <a href="https://colab.research.google.com/github/smritisrikanth/Machine-Learning/blob/main/hw5/.ipynb_checkpoints/hw5_lab-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Homework 5: Lab (13 points)
# ##Name: Hannah Qu (hqu6), Smriti Srikanth (ssrikan2)

# %% [markdown]
# Please refer to the PDF description for homework 5 for a detailed description of the goals of this assignment.
#
# You will hand in a PDF of this notebook. Please be sure to clearly answer each question listed at the end of the notebook.

# %% [markdown]
# ##Setup the code.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ##Load the Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/smritisrikanth/Machine-Learning/main/hw5/BPD_2012_2017.csv")
print(len(df))
# Drop missing values
df = df.dropna(subset=['Longitude', 'Latitude'])
# Show first 3 rows
df.head(3)
# Out:
# 276529
#     CrimeDate CrimeTime CrimeCode           Location          Description  \
# 0  09/02/2017  23:30:00       3JK    4200 AUDREY AVE  ROBBERY - RESIDENCE
# 1  09/02/2017  23:00:00        7A  800 NEWINGTON AVE           AUTO THEFT
# 2  09/02/2017  22:53:00        9S      600 RADNOR AV             SHOOTING
#
#   Inside/Outside   Weapon   Post  District    Neighborhood  Longitude  \
# 0              I    KNIFE  913.0  SOUTHERN        Brooklyn  -76.60541
# 1              O      NaN  133.0   CENTRAL  Reservoir Hill  -76.63217
# 2        Outside  FIREARM  524.0  NORTHERN  Winston-Govans  -76.60697
#
#    Latitude                       Location 1     Premise  Total Incidents
# 0  39.22951  (39.2295100000, -76.6054100000)  ROW/TOWNHO                1
# 1  39.31360  (39.3136000000, -76.6321700000)      STREET                1
# 2  39.34768  (39.3476800000, -76.6069700000)      Street                1

# %%
X = df[['Longitude', 'Latitude']].to_numpy()
# We don't need a test set for this task, so we use the whole dataset as the training set
plt.figure(figsize=(15,15))
plt.scatter(X[:,0], X[:,1], 2)

# %% [markdown]
# ##Define the K-Means Model (TODO)

# %%
class Kmeans:
    def __init__(self, n_clusters, prot = None):
        self.n_clusters = n_clusters
        
    def pairwise_distance(self, X, C):
        # Calculate the pairwise Euclidean distance between two numpy arrays X and C
        # X: N x D, i.e. N points in X
        # C: K x D, i.e. K points in C
        # return: N x K
        dists = np.empty([X.shape[0], C.shape[0]])
        for i in range(X.shape[0]):
            for k in range(C.shape[0]):
                dists[i][k] = np.linalg.norm(X[i]-C[k]) 
        return dists
    
    def fit(self, X_train, max_iter=100):
        n_samples = X_train.shape[0]
        
        #########################Step 1##########################
        # 1.1 Assign a random point as the prototype for each cluster
        prot_ind = np.random.randint(0, n_samples, self.n_clusters)
        self.prot = X_train[prot_ind]
        
        # 1.2 Calculate the distance between samples and initial prototypes
        # You may use the self.pairwise_distance function
        d = self.pairwise_distance(X_train, self.prot)
        # 1.3 Assign points to clusters
        centroids = np.zeros([n_samples, self.n_clusters])
        for i in range(n_samples):
            index = np.argmin(d[i])
            centroids[i][index] = 1
        
        # Start iterative training
        for n_iter in range(max_iter):
            ######################Step 2#########################
            # Update the prototypes
            for i in range(self.n_clusters):
                sum_num = np.zeros([1, X_train.shape[1]])
                sum_den = 0
                for j in range(n_samples):
                    if centroids[j][i] == 1:
                        sum_num = np.add(sum_num, X_train[j])
                        sum_den += 1
                self.prot[i] = sum_num/sum_den
                    
                
            ######################Step 3#########################
            # 3.1 Calculate the updated distance between samples and prototypes
            # You may use the self.pairwise_distance function
            d = self.pairwise_distance(X_train, self.prot)
            # 3.2 Assign points to clusters
            r_prev = centroids
            centroids = np.zeros([n_samples, self.n_clusters])
            for i in range(n_samples):
                index = np.argmin(d[i])
                centroids[i][index] = 1
        
            ######################Step 4#########################
            # Calculate the inertia
            inertia = 0
            for i in range(n_samples):
                inertia += np.min(d[i])
            if (n_iter+1) % 10 == 0:
                print("#Iteration: ", n_iter+1, "; inertia: {:.2f}".format(inertia))
                             
            ######################Step 5#########################
            # Check convergence: whether new cluster assignments are the same as previous cluster assignments
            if np.array_equal(r_prev, centroids):
                print("Converged at iteration {0} with inertia {1:.2f}!".format(str(n_iter+1), inertia))
                break
            
        return inertia

    def predict(self, X):
        # Predict the cluster assignments for examples
        # return: an numpy array with the length of X.shape[0]
        clusters = np.zeros(X.shape[0])

        d = self.pairwise_distance(X, self.prot)
        for i in range(len(clusters)):
            index = np.argmin(d[i])
            clusters[i] = index
        
        return clusters

# %% [markdown]
# ##Find the Elbow

# %%
def plot_tune_n_clusters(X_train, max_clusters, max_iter=40):
    inertias = []
    for k in range(max_clusters):
        kmeans = Kmeans(k+1)
        print()
        print("#Cluster: ", (k+1))
        inertias.append(kmeans.fit(X_train, max_iter))
    plt.plot(np.arange(max_clusters) + 1, inertias)
    plt.show()
    return inertias

# %% [markdown]
# Q1. (11 points) Show the plot of inertia with number of clusters from 1 to 15. Report which number of clusters is at the elbow.
#
# Please train your K-Means models on a subset of X (X_small) for this question, otherwise it takes too long to finish training. In practice, you may use the whole dataset to select n_cluster, if the computational resources allow.

# %%
X_small = X[np.random.choice(X.shape[0], size=int(X.shape[0]*0.1), replace=False),:]  # Do not change this line of code, you should train kmeans on X_small for this question.
#TODO
#You might use the plot_tune_n_clusters function

plot_tune_n_clusters(X_small,15)
# Out:
# #Cluster:  1
# Converged at iteration 0 with inertia 1255.98!
#
# #Cluster:  2
# #Iteration:  9 ; inertia: 929.35
# Converged at iteration 15 with inertia 929.36!
#
# #Cluster:  3
# #Iteration:  9 ; inertia: 783.38
# Converged at iteration 13 with inertia 783.44!
#
# #Cluster:  4
# #Iteration:  9 ; inertia: 692.68
# #Iteration:  19 ; inertia: 688.40
# Converged at iteration 26 with inertia 688.36!
#
# #Cluster:  5
# #Iteration:  9 ; inertia: 649.75
# #Iteration:  19 ; inertia: 650.48
# #Iteration:  29 ; inertia: 650.98
# Converged at iteration 29 with inertia 650.98!
#
# #Cluster:  6
# #Iteration:  9 ; inertia: 570.68
# #Iteration:  19 ; inertia: 570.49
# Converged at iteration 25 with inertia 570.53!
#
# #Cluster:  7
# #Iteration:  9 ; inertia: 545.49
# #Iteration:  19 ; inertia: 543.52
# #Iteration:  29 ; inertia: 508.10
# #Iteration:  39 ; inertia: 505.37
#
# #Cluster:  8
# #Iteration:  9 ; inertia: 479.94
# #Iteration:  19 ; inertia: 480.36
# Converged at iteration 24 with inertia 480.25!
#
# #Cluster:  9
# #Iteration:  9 ; inertia: 482.41
# #Iteration:  19 ; inertia: 457.93
# #Iteration:  29 ; inertia: 444.01
# #Iteration:  39 ; inertia: 444.13
#
# #Cluster:  10
# #Iteration:  9 ; inertia: 425.28
# #Iteration:  19 ; inertia: 425.31
# Converged at iteration 24 with inertia 425.36!
#
# #Cluster:  11
# #Iteration:  9 ; inertia: 393.12
# #Iteration:  19 ; inertia: 392.42
# Converged at iteration 24 with inertia 392.39!
#
# #Cluster:  12
# #Iteration:  9 ; inertia: 397.79
# #Iteration:  19 ; inertia: 392.44
# #Iteration:  29 ; inertia: 388.07
# #Iteration:  39 ; inertia: 376.50
#
# #Cluster:  13
# #Iteration:  9 ; inertia: 384.60
# #Iteration:  19 ; inertia: 378.63
# #Iteration:  29 ; inertia: 377.61
# #Iteration:  39 ; inertia: 377.88
#
# #Cluster:  14
# #Iteration:  9 ; inertia: 363.59
# #Iteration:  19 ; inertia: 360.42
# #Iteration:  29 ; inertia: 359.92
# #Iteration:  39 ; inertia: 359.74
#
# #Cluster:  15
# #Iteration:  9 ; inertia: 359.59
# #Iteration:  19 ; inertia: 348.83
# #Iteration:  29 ; inertia: 344.39
# #Iteration:  39 ; inertia: 343.46
# [1255.977948850973,
#  929.3612684282115,
#  783.4416296148336,
#  688.3551586705636,
#  650.9844632913132,
#  570.5267868821546,
#  505.3675500232882,
#  480.24737195695616,
#  444.12500729027903,
#  425.35655700331694,
#  392.3943906094377,
#  376.5038234616884,
#  377.87747090000533,
#  359.7359697823557,
#  343.4649606207365]

# %% [markdown]
# Number of clusters at elbow: 4

# %% [markdown]
# ##Visualization

# %%
def plot_clusters(kmeans, X_train, cluster_ids):
    plt.figure(figsize=(15,15))
    print(cluster_ids)
    for i in range(np.max(cluster_ids)+1):
        plt.scatter(X_train[cluster_ids == i, 0] , X_train[cluster_ids == i, 1] , s=2, label = i)
        plt.scatter(kmeans.prot[i,0], kmeans.prot[i, 1], label=i, s=500, marker="*")
    plt.show()

# %% [markdown]
# Q2. (2 points) Train your model with the selected number of clusters in Q1 and  plot the cluster assignments using the *plot_clusters* function.
#
# Train on the whole dataset for this question.

# %%
#TODO
#You might use the plot_cluster function

kmeans = Kmeans(4)
kmeans.fit(X)
cluster_ids = kmeans.predict(X)

plot_clusters(kmeans, X, cluster_ids.astype(int))
# Out:
# #Iteration:  10 ; inertia: 6963.98
# #Iteration:  20 ; inertia: 6954.74
# #Iteration:  30 ; inertia: 6919.08
# #Iteration:  40 ; inertia: 6848.32
# #Iteration:  50 ; inertia: 6835.19
# #Iteration:  60 ; inertia: 6844.54
# Converged at iteration 61 with inertia 6844.54!
# [2 1 3 ... 2 3 1]
